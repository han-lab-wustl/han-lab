# %%
'''
Training Data is a N*T*n tensor, N is the number of samples, T is the interval,
n is number of neurons.
Training Data is a N*1*1 tensor, N is the number of samples, 1*1 represents the
output dimension, which is the position of last time point.
Testing Data is a N'*T*n tensor.
Testing label is a N*1*1 tensor.
E.g.,
TrainingData = create_subsequences(np.transpose(X, TimeInterval))
TrainingLabel = Y[TimeInterval-1:].reshape(-1,1)
X is dFF, Y is corresponding position.
'''
# Out:
# "\nTraining Data is a N*T*n tensor, N is the number of samples, T is the interval,\nn is number of neurons.\nTraining Data is a N*1*1 tensor, N is the number of samples, 1*1 represents the\noutput dimension, which is the position of last time point.\nTesting Data is a N'*T*n tensor.\nTesting label is a N*1*1 tensor.\nE.g.,\nTrainingData = create_subsequences(np.transpose(X, TimeInterval))\nTrainingLabel = Y[TimeInterval-1:].reshape(-1,1)\nX is dFF, Y is corresponding position.\n"

# %%
import torch, os, glob
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import pickle
import numpy as np
import matplotlib.pyplot as plt
import sys
np.set_printoptions(threshold=sys.maxsize)
import scipy, pandas as pd, random
from sklearn.preprocessing import MinMaxScaler

class LSTMModel(nn.Module):
    def __init__(self, input_dim, hidden_dim = 256, output_dim = 1, 
        num_layers = 2):
        # hidden_dim = height of network
        # layers = weight of network
        super(LSTMModel, self).__init__()
        # Initialize the LSTM, Hidden Layer, and Output Layer
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_dim, hidden_dim, num_layers, 
                dropout = 0.0, batch_first=True)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        # Initialize hidden state and cell state
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_dim).to(x.device)

        # Forward propagate the LSTM
        out, _ = self.lstm(x, (h0, c0))

        # Pass the output of the last time step to the classifier
        out = self.fc(out[:, -1, :])
        
        return out

def create_subsequences(time_series, subsequence_length=20):
    num_subsequences = len(time_series) - subsequence_length + 1
    subsequences = [time_series[i:i+subsequence_length] for i in range(num_subsequences)]
    return np.array(subsequences)

class CreateTimeSeriesData(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def __getitem__(self, i):
        return self.x[i], self.y[i]

# %%
# import raw data
with open("Z:\dcts_com_opto.p", "rb") as fp: #unpickle
        dcts = pickle.load(fp)
conddf = pd.read_csv(r"Z:\condition_df\conddf_neural_com.csv", index_col=None)
# day
dd=17

# %%
# make models for all animals/days
for dd in range(len(conddf)):
    if conddf.in_type.values[dd]=='vip':
        testpth = glob.glob(os.path.join(savepth, f'model_dd{dd:02d}*'), recursive=True)
        if len(testpth)==0:
            savepth = rf'Z:\\models_lstm_inactive'    
            dct = dcts[dd]
            day=conddf.days.values[dd]
            animal = conddf.animals.values[dd]
            params_pth = rf"Y:\analysis\fmats\{animal}\days\{animal}_day{day:03d}_plane0_Fall.mat"
            print(params_pth)
            fall = scipy.io.loadmat(params_pth, variable_names=['dFF', 'forwardvel', 'ybinned', 'iscell',
                                        'trialnum', 'bordercells', 'changeRewLoc', 'licks'])
            inactive = dcts[dd]['inactive']
            changeRewLoc = np.hstack(fall['changeRewLoc']) 
            eptest = conddf.optoep.values[dd]
            eps = np.where(changeRewLoc>0)[0]
            rewlocs = changeRewLoc[eps]
            eps = np.append(eps, len(changeRewLoc)) 
            if conddf.optoep.values[dd]<2: 
                eptest = random.randint(2,3)   
                if len(eps)<4: eptest = 2 # if no 3 epochs
            trialnum = np.hstack(fall['trialnum'])
            comp = [eptest-2,eptest-1] # eps to compare  
            other_ep = [xx for xx in range(len(eps)-1) if xx not in comp]
            # filter iscell
            dff = fall['dFF'][:,(fall['iscell'][:,0].astype(bool)) & (~fall['bordercells'][0].astype(bool))]
            dff = dff[:,dct['inactive']]
            # remove nans
            dff[:, sum(np.isnan(dff))>0] = 0
            dff_per_ep = [dff[eps[xx]:eps[xx+1]] for xx in range(len(eps)-1)]
            trialnum_per_ep = [trialnum[eps[xx]:eps[xx+1]] for xx in range(len(eps)-1)]
            # get a subset of trials
            dff_per_ep_trials = [dff_per_ep[ii][((trialnum_per_ep[ii]>2) & (trialnum_per_ep[ii]<=10)) | (trialnum_per_ep[ii]>15)] for ii in range(len(eps)-1)]
            dff_per_ep_trials_test = [dff_per_ep[ii][(trialnum_per_ep[ii]>10) & (trialnum_per_ep[ii]<16)] for ii in range(len(eps)-1)]
            position = fall['ybinned'][0]
            position_per_ep = [position[eps[xx]:eps[xx+1]] for xx in range(len(eps)-1)]
            # get a subset of trials
            position_per_ep_trials = [position_per_ep[ii][((trialnum_per_ep[ii]>2) & (trialnum_per_ep[ii]<=10)) | (trialnum_per_ep[ii]>15)] for ii in range(len(eps)-1)]
            position_per_ep_trials_test = [position_per_ep[ii][(trialnum_per_ep[ii]>10) & (trialnum_per_ep[ii]<16)] for ii in range(len(eps)-1)]
            # licks
            licks = fall['licks'][0]
            licks_per_ep = [licks[eps[xx]:eps[xx+1]] for xx in range(len(eps)-1)]
            # get a subset of trials
            licks_per_ep_trials = [licks_per_ep[ii][((trialnum_per_ep[ii]>2) & (trialnum_per_ep[ii]<=10)) | (trialnum_per_ep[ii]>15)] for ii in range(len(eps)-1)]
            licks_per_ep_trials_test = [licks_per_ep[ii][(trialnum_per_ep[ii]>10) & (trialnum_per_ep[ii]<16)] for ii in range(len(eps)-1)]
                #prepare variables 
            TimeInterval = 15 # frames
            train = dff_per_ep_trials[comp[0]]
            print(train.shape)
            if train.shape[1]>0:
                test = dff_per_ep_trials_test[comp[0]]
                # TODO: use a couple trials from same ep as testing
                # use different epochs for further testing
                train_pos = position_per_ep_trials[comp[0]]
                TrainingLabel = train_pos[TimeInterval-1:].reshape(-1,1)
                test_pos = position_per_ep_trials_test[comp[0]]
                TestLabel = test_pos[TimeInterval-1:].reshape(-1,1)

                TrainingData = create_subsequences(train,TimeInterval)
                batch_size = 128
                input_size = TrainingData.shape[-1] # number of cells
                output_size = 1

                Train_dataset = CreateTimeSeriesData(TrainingData, TrainingLabel)
                Train_loader = DataLoader(dataset=Train_dataset, batch_size=batch_size, 
                            shuffle=True, drop_last = True)
                TestData = create_subsequences(test,TimeInterval)
                Test_dataset = CreateTimeSeriesData(TestData, TestLabel)
                Test_loader = DataLoader(dataset=Test_dataset, batch_size=batch_size,
                            shuffle=False, drop_last = True)
                
                # define the model & train
                # TODO: add transfer learning
                model = LSTMModel(input_size, output_dim = output_size)
                device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
                print(device)
                model = model.to(device)
                criterion = nn.MSELoss()  # For regression tasks
                # criterion = nn.CrossEntropyLoss()
                optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, weight_decay = 1e-9)

                # Example training loop
                l = []
                val_l = []
                num_epochs = 2000
                    
                for epoch in range(num_epochs):
                    train_loss = 0.0
                    for inputs, targets in Train_loader:
                        # Forward pass
                        inputs, targets = inputs.to(device).float(), targets.to(device).float()
                        outputs = model(inputs)
                        loss = criterion(outputs, targets)

                        # Backward pass and optimization
                        optimizer.zero_grad()
                        loss.backward()
                        optimizer.step()
                        train_loss += loss.item()

                    l.append(train_loss/len(Train_loader))
                    if epoch % 20 == 0:
                        print('Epoch [{}/{}], Loss: {:.4f}'.format(epoch+1, num_epochs, train_loss/len(Train_loader)))
                        val_loss = 0.0
                        for inputs, targets in Test_loader:
                            # Forward pass
                            inputs, targets = inputs.to(device).float(), targets.to(device).float()
                            outputs = model(inputs)
                            loss = criterion(outputs, targets)
                            val_loss += loss.item()
                            val_l.append(val_loss/len(Test_loader))
                        print('Validation Loss: {:.4f}'.format(val_loss/len(Test_loader)))
                # save        
                torch.save(model.state_dict(), os.path.join(savepth, f'model_dd{dd:02d}_epcompare{comp[0]}-{comp[1]}.pt'))
# Out:
# Y:\analysis\fmats\e200\days\e200_day065_plane0_Fall.mat
# (9108, 4)
# cuda:0
# Epoch [1/2000], Loss: 9689.7198
# Validation Loss: 8181.7995
# Epoch [21/2000], Loss: 7763.6757
# Validation Loss: 6480.3824
# Epoch [41/2000], Loss: 7246.5717
# Validation Loss: 6030.9304
# Epoch [61/2000], Loss: 6773.1202
# Validation Loss: 5625.7355
# Epoch [81/2000], Loss: 6332.8464
# Validation Loss: 5249.8298
# Epoch [101/2000], Loss: 5917.9204
# Validation Loss: 4899.5817
# Epoch [121/2000], Loss: 5528.9094
# Validation Loss: 4573.5229
# Epoch [141/2000], Loss: 5158.6501
# Validation Loss: 4268.6475
# Epoch [161/2000], Loss: 4814.4398
# Validation Loss: 3989.1363
# Epoch [181/2000], Loss: 4493.9408
# Validation Loss: 3733.6260
# Epoch [201/2000], Loss: 4199.6438
# Validation Loss: 3501.6444
# Epoch [221/2000], Loss: 3925.8130
# Validation Loss: 3293.1581
# Epoch [241/2000], Loss: 3678.3999
# Validation Loss: 3107.8203
# Epoch [261/2000], Loss: 3453.0676
# Validation Loss: 2945.5386
# Epoch [281/2000], Loss: 3251.1848
# Validation Loss: 2806.1180
# Epoch [301/2000], Loss: 3070.3010
# Validation Loss: 2688.9745
# Epoch [321/2000], Loss: 2914.7473
# Validation Loss: 2593.0693
# Epoch [341/2000], Loss: 2775.3700
# Validation Loss: 2516.6822
# Epoch [361/2000], Loss: 2657.4545
# Validation Loss: 2456.1158
# Epoch [381/2000], Loss: 2564.5289
# Validation Loss: 2422.1550
# Epoch [401/2000], Loss: 2494.9307
# Validation Loss: 2407.0289
# Epoch [421/2000], Loss: 2443.0077
# Validation Loss: 2407.4364
# Epoch [441/2000], Loss: 2409.4144
# Validation Loss: 2420.4126
# Epoch [461/2000], Loss: 2391.2410
# Validation Loss: 2441.0106
# Epoch [481/2000], Loss: 2382.8456
# Validation Loss: 2461.3333
# Epoch [501/2000], Loss: 2376.4869
# Validation Loss: 2476.1339
# Epoch [521/2000], Loss: 2377.2592
# Validation Loss: 2484.3857
# Epoch [541/2000], Loss: 2369.5842
# Validation Loss: 2480.8818
# Epoch [561/2000], Loss: 2365.2708
# Validation Loss: 2482.8775
# Epoch [581/2000], Loss: 2365.4117
# Validation Loss: 2483.8528
# Epoch [601/2000], Loss: 2364.4166
# Validation Loss: 2482.1985
# Epoch [621/2000], Loss: 2361.6400
# Validation Loss: 2482.9697
# Epoch [641/2000], Loss: 2361.4253
# Validation Loss: 2482.0732
# Epoch [661/2000], Loss: 2357.9246
# Validation Loss: 2479.6997
# Epoch [681/2000], Loss: 2356.1943
# Validation Loss: 2479.6270
# Epoch [701/2000], Loss: 2354.6025
# Validation Loss: 2476.6790
# Epoch [721/2000], Loss: 2346.1668
# Validation Loss: 2471.1942
# Epoch [741/2000], Loss: 2344.7920
# Validation Loss: 2471.2987
# Epoch [761/2000], Loss: 2343.5366
# Validation Loss: 2469.5520
# Epoch [781/2000], Loss: 2342.3038
# Validation Loss: 2467.8950
# Epoch [801/2000], Loss: 2339.6379
# Validation Loss: 2468.9718
# Epoch [821/2000], Loss: 2332.4334
# Validation Loss: 2460.5864
# Epoch [841/2000], Loss: 2328.7307
# Validation Loss: 2460.6447
# Epoch [861/2000], Loss: 2327.2767
# Validation Loss: 2460.5506
# Epoch [881/2000], Loss: 2325.8181
# Validation Loss: 2459.8575
# Epoch [901/2000], Loss: 2316.0823
# Validation Loss: 2453.3490
# Epoch [921/2000], Loss: 2309.0008
# Validation Loss: 2446.8154
# Epoch [941/2000], Loss: 2302.2863
# Validation Loss: 2441.4881
# Epoch [961/2000], Loss: 2297.7661
# Validation Loss: 2441.5310
# Epoch [981/2000], Loss: 2280.9454
# Validation Loss: 2429.8951
# Epoch [1001/2000], Loss: 2266.1734
# Validation Loss: 2415.6484
# Epoch [1021/2000], Loss: 2261.4223
# Validation Loss: 2412.9220
# Epoch [1041/2000], Loss: 2254.7682
# Validation Loss: 2410.3958
# Epoch [1061/2000], Loss: 2238.4213
# Validation Loss: 2393.9131
# Epoch [1081/2000], Loss: 2227.7669
# Validation Loss: 2387.2240
# Epoch [1101/2000], Loss: 2205.9794
# Validation Loss: 2364.5057
# Epoch [1121/2000], Loss: 2080.5827
# Validation Loss: 2188.3429
# Epoch [1141/2000], Loss: 2062.0667
# Validation Loss: 2184.3215
# Epoch [1161/2000], Loss: 2050.2337
# Validation Loss: 2188.6219
# Epoch [1181/2000], Loss: 2040.5554
# Validation Loss: 2190.8560
# Epoch [1201/2000], Loss: 2031.4600
# Validation Loss: 2202.8543
# Epoch [1221/2000], Loss: 2025.1547
# Validation Loss: 2194.6275
# Epoch [1241/2000], Loss: 2016.1214
# Validation Loss: 2216.8301
# Epoch [1261/2000], Loss: 2013.7848
# Validation Loss: 2234.2008
# Epoch [1281/2000], Loss: 2004.4418
# Validation Loss: 2228.6514
# Epoch [1301/2000], Loss: 2001.2668
# Validation Loss: 2232.9367
# Epoch [1321/2000], Loss: 1993.5258
# Validation Loss: 2225.5554
# Epoch [1341/2000], Loss: 1992.3498
# Validation Loss: 2210.5565
# Epoch [1361/2000], Loss: 1983.6956
# Validation Loss: 2189.6208
# Epoch [1381/2000], Loss: 1975.1054
# Validation Loss: 2214.1712
# Epoch [1401/2000], Loss: 1971.7474
# Validation Loss: 2195.0264
# Epoch [1421/2000], Loss: 1958.9898
# Validation Loss: 2169.8696
# Epoch [1441/2000], Loss: 1950.4895
# Validation Loss: 2158.6817
# Epoch [1461/2000], Loss: 1947.0189
# Validation Loss: 2162.5537
# Epoch [1481/2000], Loss: 1936.4070
# Validation Loss: 2178.7161
# Epoch [1501/2000], Loss: 1925.6304
# Validation Loss: 2149.5588
# Epoch [1521/2000], Loss: 1919.0987
# Validation Loss: 2153.6829
# Epoch [1541/2000], Loss: 1918.9739
# Validation Loss: 2131.0332
# Epoch [1561/2000], Loss: 1910.4253
# Validation Loss: 2147.2115
# Epoch [1581/2000], Loss: 1902.7315
# Validation Loss: 2100.2653
# Epoch [1601/2000], Loss: 1895.3806
# Validation Loss: 2135.3421
# Epoch [1621/2000], Loss: 1886.5479
# Validation Loss: 2136.5995
# Epoch [1641/2000], Loss: 1890.3192
# Validation Loss: 2158.0303
# Epoch [1661/2000], Loss: 1876.7779
# Validation Loss: 2123.8228
# Epoch [1681/2000], Loss: 1870.0559
# Validation Loss: 2168.2975
# Epoch [1701/2000], Loss: 1870.2546
# Validation Loss: 2171.0245
# Epoch [1721/2000], Loss: 1857.5813
# Validation Loss: 2160.1181
# Epoch [1741/2000], Loss: 1856.1552
# Validation Loss: 2211.6773
# Epoch [1761/2000], Loss: 1837.5755
# Validation Loss: 2212.3806
# Epoch [1781/2000], Loss: 1827.1222
# Validation Loss: 2210.1433
# Epoch [1801/2000], Loss: 1826.7002
# Validation Loss: 2194.9366
# Epoch [1821/2000], Loss: 1815.2094
# Validation Loss: 2217.0552
# Epoch [1841/2000], Loss: 1811.4517
# Validation Loss: 2227.2611
# Epoch [1861/2000], Loss: 1800.1887
# Validation Loss: 2236.4662
# Epoch [1881/2000], Loss: 1789.1551
# Validation Loss: 2286.7074
# Epoch [1901/2000], Loss: 1784.7582
# Validation Loss: 2274.8709
# Epoch [1921/2000], Loss: 1775.4688
# Validation Loss: 2292.9957
# Epoch [1941/2000], Loss: 1764.7966
# Validation Loss: 2231.4844
# Epoch [1961/2000], Loss: 1764.6962
# Validation Loss: 2282.6897
# Epoch [1981/2000], Loss: 1761.4997
# Validation Loss: 2297.5726
# Y:\analysis\fmats\e200\days\e200_day066_plane0_Fall.mat
# (7848, 4)
# cuda:0
# Epoch [1/2000], Loss: 12589.7121
# Validation Loss: 12715.4504
# Epoch [21/2000], Loss: 10487.2223
# Validation Loss: 10606.7345
# Epoch [41/2000], Loss: 9966.2339
# Validation Loss: 10077.4030
# Epoch [61/2000], Loss: 9492.0514
# Validation Loss: 9601.7887
# Epoch [81/2000], Loss: 9040.4970
# Validation Loss: 9144.1831
# Epoch [101/2000], Loss: 8598.5228
# Validation Loss: 8713.5248
# Epoch [121/2000], Loss: 8183.1000
# Validation Loss: 8302.2693
# Epoch [141/2000], Loss: 7799.6132
# Validation Loss: 7909.4009
# Epoch [161/2000], Loss: 7416.7803
# Validation Loss: 7534.7372
# Epoch [181/2000], Loss: 7070.4413
# Validation Loss: 7177.9048
# Epoch [201/2000], Loss: 6729.3925
# Validation Loss: 6839.2307
# Epoch [221/2000], Loss: 6408.7773
# Validation Loss: 6518.4233
# Epoch [241/2000], Loss: 6109.3869
# Validation Loss: 6212.3985
# Epoch [261/2000], Loss: 5820.8760
# Validation Loss: 5926.3555
# Epoch [281/2000], Loss: 5551.3033
# Validation Loss: 5658.2852
# Epoch [301/2000], Loss: 5303.9986
# Validation Loss: 5408.2774
# Epoch [321/2000], Loss: 5069.1453
# Validation Loss: 5175.8801
# Epoch [341/2000], Loss: 4858.9782
# Validation Loss: 4961.0962
# Epoch [361/2000], Loss: 4656.3881
# Validation Loss: 4764.0765
# Epoch [381/2000], Loss: 4477.3149
# Validation Loss: 4584.2917
# Epoch [401/2000], Loss: 4320.3574
# Validation Loss: 4421.8163
# Epoch [421/2000], Loss: 4174.4108
# Validation Loss: 4274.4352
# Epoch [441/2000], Loss: 4045.7908
# Validation Loss: 4145.8604
# Epoch [461/2000], Loss: 3928.7126
# Validation Loss: 4034.2223
# Epoch [481/2000], Loss: 3836.9496
# Validation Loss: 3938.7909
# Epoch [501/2000], Loss: 3757.9760
# Validation Loss: 3857.9676
# Epoch [521/2000], Loss: 3689.1855
# Validation Loss: 3778.6126
# Epoch [541/2000], Loss: 3639.8280
# Validation Loss: 3722.9299
# Epoch [561/2000], Loss: 3601.3158
# Validation Loss: 3684.7364
# Epoch [581/2000], Loss: 3575.3961
# Validation Loss: 3639.3974
# Epoch [601/2000], Loss: 3559.0096
# Validation Loss: 3622.5113
# Epoch [621/2000], Loss: 3548.7606
# Validation Loss: 3614.9642
# Epoch [641/2000], Loss: 3538.2431
# Validation Loss: 3585.9105
# Epoch [661/2000], Loss: 3535.0141
# Validation Loss: 3587.4497
# Epoch [681/2000], Loss: 3531.2070
# Validation Loss: 3589.7439
# Epoch [701/2000], Loss: 3532.4047
# Validation Loss: 3585.4351
# Epoch [721/2000], Loss: 3522.5999
# Validation Loss: 3574.7158
# Epoch [741/2000], Loss: 3513.3173
# Validation Loss: 3567.4968
# Epoch [761/2000], Loss: 3512.5295
# Validation Loss: 3558.7215
# Epoch [781/2000], Loss: 3515.3228
# Validation Loss: 3554.5251
# Epoch [801/2000], Loss: 3501.6999
# Validation Loss: 3525.5450
# Epoch [821/2000], Loss: 3500.6223
# Validation Loss: 3521.8703
# Epoch [841/2000], Loss: 3504.1547
# Validation Loss: 3530.8839
# Epoch [861/2000], Loss: 3499.2634
# Validation Loss: 3523.0568
# Epoch [881/2000], Loss: 3489.3717
# Validation Loss: 3487.5443
# Epoch [901/2000], Loss: 3489.1830
# Validation Loss: 3504.0567
# Epoch [921/2000], Loss: 3485.5837
# Validation Loss: 3479.0710
# Epoch [941/2000], Loss: 3486.9044
# Validation Loss: 3486.8491
# Epoch [961/2000], Loss: 3485.9592
# Validation Loss: 3492.5678
# Epoch [981/2000], Loss: 3473.8487
# Validation Loss: 3459.3480
# Epoch [1001/2000], Loss: 3473.3621
# Validation Loss: 3444.3584
# Epoch [1021/2000], Loss: 3474.9781
# Validation Loss: 3455.2012
# Epoch [1041/2000], Loss: 3465.3050
# Validation Loss: 3409.7036
# Epoch [1061/2000], Loss: 3457.7354
# Validation Loss: 3423.3369
# Epoch [1081/2000], Loss: 3446.8781
# Validation Loss: 3415.9241
# Epoch [1101/2000], Loss: 3443.2494
# Validation Loss: 3399.7778
# Epoch [1121/2000], Loss: 3431.0256
# Validation Loss: 3385.7600
# Epoch [1141/2000], Loss: 3426.0474
# Validation Loss: 3390.0984
# Epoch [1161/2000], Loss: 3410.2075
# Validation Loss: 3363.0788
# Epoch [1181/2000], Loss: 3395.9437
# Validation Loss: 3323.9968
# Epoch [1201/2000], Loss: 3375.8318
# Validation Loss: 3269.4659
# Epoch [1221/2000], Loss: 3350.4527
# Validation Loss: 3262.9508
# Epoch [1241/2000], Loss: 3302.8767
# Validation Loss: 3196.0357
# Epoch [1261/2000], Loss: 3274.6727
# Validation Loss: 3179.5966
# Epoch [1281/2000], Loss: 3236.0521
# Validation Loss: 3128.0399
# Epoch [1301/2000], Loss: 3227.8155
# Validation Loss: 3082.5881
# Epoch [1321/2000], Loss: 3202.3186
# Validation Loss: 3094.8926
# Epoch [1341/2000], Loss: 3190.2635
# Validation Loss: 3058.2377
# Epoch [1361/2000], Loss: 3159.5571
# Validation Loss: 3046.1181
# Epoch [1381/2000], Loss: 3148.5082
# Validation Loss: 2964.1469
# Epoch [1401/2000], Loss: 3114.6600
# Validation Loss: 2908.1130
# Epoch [1421/2000], Loss: 3101.6270
# Validation Loss: 2881.2566
# Epoch [1441/2000], Loss: 3092.2531
# Validation Loss: 2878.9350
# Epoch [1461/2000], Loss: 3069.3978
# Validation Loss: 2834.3187
# Epoch [1481/2000], Loss: 3061.4172
# Validation Loss: 2805.4159
# Epoch [1501/2000], Loss: 3057.9034
# Validation Loss: 2752.2288
# Epoch [1521/2000], Loss: 3035.6550
# Validation Loss: 2737.9483
# Epoch [1541/2000], Loss: 3032.6744
# Validation Loss: 2721.4181
# Epoch [1561/2000], Loss: 3019.1167
# Validation Loss: 2690.8561
# Epoch [1581/2000], Loss: 2999.1528
# Validation Loss: 2702.0500
# Epoch [1601/2000], Loss: 2985.4536
# Validation Loss: 2676.8175
# Epoch [1621/2000], Loss: 2983.3817
# Validation Loss: 2655.8578
# Epoch [1641/2000], Loss: 2963.4954
# Validation Loss: 2623.6127
# Epoch [1661/2000], Loss: 2955.9341
# Validation Loss: 2645.9752
# Epoch [1681/2000], Loss: 2937.1163
# Validation Loss: 2590.8572
# Epoch [1701/2000], Loss: 2926.8882
# Validation Loss: 2633.3390
# Epoch [1721/2000], Loss: 2934.4980
# Validation Loss: 2630.8169
# Epoch [1741/2000], Loss: 2919.1561
# Validation Loss: 2550.9730
# Epoch [1761/2000], Loss: 2895.0010
# Validation Loss: 2585.1717
# Epoch [1781/2000], Loss: 2910.4531
# Validation Loss: 2502.7853
# Epoch [1801/2000], Loss: 2886.0487
# Validation Loss: 2633.9296
# Epoch [1821/2000], Loss: 2876.8896
# Validation Loss: 2538.9019
# Epoch [1841/2000], Loss: 2853.8960
# Validation Loss: 2526.6142
# Epoch [1861/2000], Loss: 2852.3688
# Validation Loss: 2586.0477
# Epoch [1881/2000], Loss: 2848.9725
# Validation Loss: 2517.5859
# Epoch [1901/2000], Loss: 2831.5724
# Validation Loss: 2578.6879
# Epoch [1921/2000], Loss: 2832.5279
# Validation Loss: 2485.9738
# Epoch [1941/2000], Loss: 2806.5979
# Validation Loss: 2533.5424
# Epoch [1961/2000], Loss: 2810.7025
# Validation Loss: 2490.8370
# Epoch [1981/2000], Loss: 2795.2812
# Validation Loss: 2491.5096
# Y:\analysis\fmats\e200\days\e200_day067_plane0_Fall.mat
# (8286, 0)
# Y:\analysis\fmats\e200\days\e200_day068_plane0_Fall.mat
# (11541, 3)
# cuda:0
# Epoch [1/2000], Loss: 7644.3363
# Validation Loss: 7718.8790
# Epoch [21/2000], Loss: 6008.4741
# Validation Loss: 6068.0879
# Epoch [41/2000], Loss: 5521.6258
# Validation Loss: 5579.1692
# Epoch [61/2000], Loss: 5088.2555
# Validation Loss: 5146.8695
# Epoch [81/2000], Loss: 4699.1466
# Validation Loss: 4756.5162
# Epoch [101/2000], Loss: 4347.3109
# Validation Loss: 4402.5148
# Epoch [121/2000], Loss: 4033.8715
# Validation Loss: 4088.2123
# Epoch [141/2000], Loss: 3761.8936
# Validation Loss: 3812.6096
# Epoch [161/2000], Loss: 3525.3913
# Validation Loss: 3574.7546
# Epoch [181/2000], Loss: 3325.9066
# Validation Loss: 3374.2316
# Epoch [201/2000], Loss: 3163.5572
# Validation Loss: 3210.0997
# Epoch [221/2000], Loss: 3036.4662
# Validation Loss: 3081.4606
# Epoch [241/2000], Loss: 2939.2704
# Validation Loss: 2985.9550
# Epoch [261/2000], Loss: 2878.5296
# Validation Loss: 2922.3459
# Epoch [281/2000], Loss: 2845.3443
# Validation Loss: 2886.3663
# Epoch [301/2000], Loss: 2827.4667
# Validation Loss: 2870.4637
# Epoch [321/2000], Loss: 2819.8750
# Validation Loss: 2863.2529
# Epoch [341/2000], Loss: 2818.9418
# Validation Loss: 2861.4545
# Epoch [361/2000], Loss: 2812.8350
# Validation Loss: 2859.0745
# Epoch [381/2000], Loss: 2810.4493
# Validation Loss: 2858.3994
# Epoch [401/2000], Loss: 2810.8986
# Validation Loss: 2857.9051
# Epoch [421/2000], Loss: 2808.5668
# Validation Loss: 2857.3571
# Epoch [441/2000], Loss: 2809.3788
# Validation Loss: 2857.1646
# Epoch [461/2000], Loss: 2803.1675
# Validation Loss: 2855.0497
# Epoch [481/2000], Loss: 2797.7814
# Validation Loss: 2853.0917
# Epoch [501/2000], Loss: 2795.9370
# Validation Loss: 2852.5433
# Epoch [521/2000], Loss: 2795.1276
# Validation Loss: 2852.2929
# Epoch [541/2000], Loss: 2794.0501
# Validation Loss: 2851.9185
# Epoch [561/2000], Loss: 2791.3141
# Validation Loss: 2851.6076
# Epoch [581/2000], Loss: 2790.1503
# Validation Loss: 2851.4018
# Epoch [601/2000], Loss: 2793.2565
# Validation Loss: 2852.8200
# Epoch [621/2000], Loss: 2787.7090
# Validation Loss: 2852.2663
# Epoch [641/2000], Loss: 2785.8302
# Validation Loss: 2850.7921
# Epoch [661/2000], Loss: 2782.0312
# Validation Loss: 2848.9370
# Epoch [681/2000], Loss: 2778.3255
# Validation Loss: 2848.7543
# Epoch [701/2000], Loss: 2777.2153
# Validation Loss: 2848.1646
# Epoch [721/2000], Loss: 2778.6903
# Validation Loss: 2848.0301
# Epoch [741/2000], Loss: 2774.8988
# Validation Loss: 2849.5034
# Epoch [761/2000], Loss: 2773.0229
# Validation Loss: 2847.7899
# Epoch [781/2000], Loss: 2772.5283
# Validation Loss: 2847.6350
# Epoch [801/2000], Loss: 2768.3683
# Validation Loss: 2846.5986
# Epoch [821/2000], Loss: 2766.9083
# Validation Loss: 2845.8964
# Epoch [841/2000], Loss: 2762.9799
# Validation Loss: 2846.4076
# Epoch [861/2000], Loss: 2760.3394
# Validation Loss: 2845.1559
# Epoch [881/2000], Loss: 2759.8252
# Validation Loss: 2844.3625
# Epoch [901/2000], Loss: 2754.7581
# Validation Loss: 2845.2537
# Epoch [921/2000], Loss: 2752.5516
# Validation Loss: 2845.5648
# Epoch [941/2000], Loss: 2751.3038
# Validation Loss: 2844.4148
# Epoch [961/2000], Loss: 2746.1533
# Validation Loss: 2847.4425
# Epoch [981/2000], Loss: 2745.9190
# Validation Loss: 2845.2113
# Epoch [1001/2000], Loss: 2740.6491
# Validation Loss: 2843.2827
# Epoch [1021/2000], Loss: 2733.9994
# Validation Loss: 2845.6952
# Epoch [1041/2000], Loss: 2731.8020
# Validation Loss: 2846.8205
# Epoch [1061/2000], Loss: 2732.4910
# Validation Loss: 2847.1361
# Epoch [1081/2000], Loss: 2731.1105
# Validation Loss: 2844.2303
# Epoch [1101/2000], Loss: 2728.0692
# Validation Loss: 2847.7720
# Epoch [1121/2000], Loss: 2723.3662
# Validation Loss: 2846.2920
# Epoch [1141/2000], Loss: 2721.0749
# Validation Loss: 2846.9770
# Epoch [1161/2000], Loss: 2719.6390
# Validation Loss: 2848.8852
# Epoch [1181/2000], Loss: 2718.1706
# Validation Loss: 2849.0383
# Epoch [1201/2000], Loss: 2716.2361
# Validation Loss: 2849.1888
# Epoch [1221/2000], Loss: 2713.4409
# Validation Loss: 2852.7639
# Epoch [1241/2000], Loss: 2713.8290
# Validation Loss: 2849.5768
# Epoch [1261/2000], Loss: 2711.5792
# Validation Loss: 2850.9804
# Epoch [1281/2000], Loss: 2710.1970
# Validation Loss: 2850.8085
# Epoch [1301/2000], Loss: 2708.6759
# Validation Loss: 2850.8277
# Epoch [1321/2000], Loss: 2708.2917
# Validation Loss: 2850.5536
# Epoch [1341/2000], Loss: 2702.7230
# Validation Loss: 2850.3417
# Epoch [1361/2000], Loss: 2701.7215
# Validation Loss: 2850.2435
# Epoch [1381/2000], Loss: 2699.1013
# Validation Loss: 2851.4445
# Epoch [1401/2000], Loss: 2698.4056
# Validation Loss: 2853.0815
# Epoch [1421/2000], Loss: 2697.7594
# Validation Loss: 2850.5482
# Epoch [1441/2000], Loss: 2696.0940
# Validation Loss: 2849.7037
# Epoch [1461/2000], Loss: 2694.0777
# Validation Loss: 2853.2892
# Epoch [1481/2000], Loss: 2693.6366
# Validation Loss: 2850.9201
# Epoch [1501/2000], Loss: 2689.9108
# Validation Loss: 2851.9135
# Epoch [1521/2000], Loss: 2689.1300
# Validation Loss: 2853.2679
# Epoch [1541/2000], Loss: 2686.5957
# Validation Loss: 2854.7307
# Epoch [1561/2000], Loss: 2684.9556
# Validation Loss: 2858.2255
# Epoch [1581/2000], Loss: 2682.3804
# Validation Loss: 2858.9018
# Epoch [1601/2000], Loss: 2680.2323
# Validation Loss: 2856.5600
# Epoch [1621/2000], Loss: 2674.1504
# Validation Loss: 2848.7318
# Epoch [1641/2000], Loss: 2663.3042
# Validation Loss: 2841.7406
# Epoch [1661/2000], Loss: 2657.4512
# Validation Loss: 2845.4579
# Epoch [1681/2000], Loss: 2647.6732
# Validation Loss: 2833.9471
# Epoch [1701/2000], Loss: 2639.4092
# Validation Loss: 2828.8066
# Epoch [1721/2000], Loss: 2630.5882
# Validation Loss: 2827.2461
# Epoch [1741/2000], Loss: 2629.0924
# Validation Loss: 2824.2887
# Epoch [1761/2000], Loss: 2623.5455
# Validation Loss: 2832.7229
# Epoch [1781/2000], Loss: 2618.2052
# Validation Loss: 2830.4708
# Epoch [1801/2000], Loss: 2612.5638
# Validation Loss: 2828.5794
# Epoch [1821/2000], Loss: 2606.3402
# Validation Loss: 2820.6438
# Epoch [1841/2000], Loss: 2601.0357
# Validation Loss: 2821.9414
# Epoch [1861/2000], Loss: 2596.9024
# Validation Loss: 2821.8278
# Epoch [1881/2000], Loss: 2594.3009
# Validation Loss: 2821.3800
# Epoch [1901/2000], Loss: 2589.5060
# Validation Loss: 2819.5118
# Epoch [1921/2000], Loss: 2588.2583
# Validation Loss: 2823.6568
# Epoch [1941/2000], Loss: 2586.2992
# Validation Loss: 2816.6057
# Epoch [1961/2000], Loss: 2579.1005
# Validation Loss: 2807.2597
# Epoch [1981/2000], Loss: 2579.7602
# Validation Loss: 2806.8430
# Y:\analysis\fmats\e200\days\e200_day069_plane0_Fall.mat
# (14990, 1)
# cuda:0
# Epoch [1/2000], Loss: 10497.1980
# Validation Loss: 9845.4046
# Epoch [21/2000], Loss: 8265.5804
# Validation Loss: 7638.1617
# Epoch [41/2000], Loss: 7488.7106
# Validation Loss: 6878.3615
# Epoch [61/2000], Loss: 6799.9795
# Validation Loss: 6205.3864
# Epoch [81/2000], Loss: 6173.8660
# Validation Loss: 5594.9775
# Epoch [101/2000], Loss: 5615.6707
# Validation Loss: 5052.2084
# Epoch [121/2000], Loss: 5122.3438
# Validation Loss: 4574.3479
# Epoch [141/2000], Loss: 4693.4984
# Validation Loss: 4160.8343
# Epoch [161/2000], Loss: 4328.2922
# Validation Loss: 3810.7418
# Epoch [181/2000], Loss: 4024.0461
# Validation Loss: 3521.3842
# Epoch [201/2000], Loss: 3771.3008
# Validation Loss: 3284.0133
# Epoch [221/2000], Loss: 3590.2690
# Validation Loss: 3117.2952
# Epoch [241/2000], Loss: 3468.8223
# Validation Loss: 3009.2564
# Epoch [261/2000], Loss: 3400.1104
# Validation Loss: 2952.3210
# Epoch [281/2000], Loss: 3372.0287
# Validation Loss: 2932.8994
# Epoch [301/2000], Loss: 3365.2702
# Validation Loss: 2930.8091
# Epoch [321/2000], Loss: 3364.3712
# Validation Loss: 2931.6108
# Epoch [341/2000], Loss: 3346.4085
# Validation Loss: 2948.6670
# Epoch [361/2000], Loss: 3341.0693
# Validation Loss: 2936.3264
# Epoch [381/2000], Loss: 3327.5994
# Validation Loss: 2951.4971
# Epoch [401/2000], Loss: 3313.5906
# Validation Loss: 2941.5986
# Epoch [421/2000], Loss: 3306.2835
# Validation Loss: 2959.5415
# Epoch [441/2000], Loss: 3292.6127
# Validation Loss: 2983.5000
# Epoch [461/2000], Loss: 3268.2912
# Validation Loss: 3023.6671
# Epoch [481/2000], Loss: 3247.3913
# Validation Loss: 3023.8710
# Epoch [501/2000], Loss: 3228.8792
# Validation Loss: 3042.5805
# Epoch [521/2000], Loss: 3220.7312
# Validation Loss: 3022.3781
# Epoch [541/2000], Loss: 3218.1152
# Validation Loss: 2998.5348
# Epoch [561/2000], Loss: 3201.2898
# Validation Loss: 3003.9326
# Epoch [581/2000], Loss: 3196.5172
# Validation Loss: 3018.1392
# Epoch [601/2000], Loss: 3186.5494
# Validation Loss: 3107.6384
# Epoch [621/2000], Loss: 3184.1856
# Validation Loss: 2982.1665
# Epoch [641/2000], Loss: 3174.7993
# Validation Loss: 3033.3379
# Epoch [661/2000], Loss: 3166.7297
# Validation Loss: 3025.9538
# Epoch [681/2000], Loss: 3163.2253
# Validation Loss: 3049.8002
# Epoch [701/2000], Loss: 3156.5144
# Validation Loss: 3048.7217
# Epoch [721/2000], Loss: 3156.5331
# Validation Loss: 3042.2405
# Epoch [741/2000], Loss: 3148.1164
# Validation Loss: 3016.8900
# Epoch [761/2000], Loss: 3144.9929
# Validation Loss: 3037.2614
# Epoch [781/2000], Loss: 3143.7271
# Validation Loss: 3097.3367
# Epoch [801/2000], Loss: 3145.0727
# Validation Loss: 2996.3291
# Epoch [821/2000], Loss: 3135.9404
# Validation Loss: 3040.9117
# Epoch [841/2000], Loss: 3141.7625
# Validation Loss: 3040.5263
# Epoch [861/2000], Loss: 3134.0943
# Validation Loss: 2992.1163
# Epoch [881/2000], Loss: 3129.6837
# Validation Loss: 3060.0893
# Epoch [901/2000], Loss: 3130.3088
# Validation Loss: 3107.8390
# Epoch [921/2000], Loss: 3124.6263
# Validation Loss: 3075.0290
# Epoch [941/2000], Loss: 3122.5811
# Validation Loss: 3047.0533
# Epoch [961/2000], Loss: 3120.9389
# Validation Loss: 3049.5544
# Epoch [981/2000], Loss: 3118.2806
# Validation Loss: 3111.9110
# Epoch [1001/2000], Loss: 3124.9857
# Validation Loss: 3115.3507
# Epoch [1021/2000], Loss: 3119.6467
# Validation Loss: 3030.3087
# Epoch [1041/2000], Loss: 3115.0763
# Validation Loss: 3106.6089
# Epoch [1061/2000], Loss: 3110.7942
# Validation Loss: 3033.8878
# Epoch [1081/2000], Loss: 3111.9696
# Validation Loss: 3021.2397
# Epoch [1101/2000], Loss: 3109.2463
# Validation Loss: 3067.0392
# Epoch [1121/2000], Loss: 3110.9435
# Validation Loss: 3053.3923
# Epoch [1141/2000], Loss: 3106.6514
# Validation Loss: 3069.5976
# Epoch [1161/2000], Loss: 3107.8573
# Validation Loss: 3081.6756
# Epoch [1181/2000], Loss: 3103.5501
# Validation Loss: 3087.6180
# Epoch [1201/2000], Loss: 3101.9562
# Validation Loss: 3054.7370
# Epoch [1221/2000], Loss: 3102.1084
# Validation Loss: 3042.9177
# Epoch [1241/2000], Loss: 3100.1226
# Validation Loss: 3047.9166
# Epoch [1261/2000], Loss: 3098.3366
# Validation Loss: 3043.3187
# Epoch [1281/2000], Loss: 3099.8753
# Validation Loss: 3079.3884
# Epoch [1301/2000], Loss: 3094.9479
# Validation Loss: 3027.7919
# Epoch [1321/2000], Loss: 3094.0691
# Validation Loss: 3024.2707
# Epoch [1341/2000], Loss: 3098.9783
# Validation Loss: 3072.8842
# Epoch [1361/2000], Loss: 3097.5686
# Validation Loss: 3011.9881
# Epoch [1381/2000], Loss: 3091.4864
# Validation Loss: 3063.2704
# Epoch [1401/2000], Loss: 3090.0327
# Validation Loss: 3049.4669
# Epoch [1421/2000], Loss: 3092.4173
# Validation Loss: 3055.5182
# Epoch [1441/2000], Loss: 3090.9621
# Validation Loss: 3088.6873
# Epoch [1461/2000], Loss: 3088.7612
# Validation Loss: 3040.5870
# Epoch [1481/2000], Loss: 3090.8485
# Validation Loss: 3068.8574
# Epoch [1501/2000], Loss: 3092.3923
# Validation Loss: 3124.2089
# Epoch [1521/2000], Loss: 3086.8235
# Validation Loss: 3062.8386
# Epoch [1541/2000], Loss: 3083.9847
# Validation Loss: 3078.9140
# Epoch [1561/2000], Loss: 3083.1275
# Validation Loss: 3064.5922
# Epoch [1581/2000], Loss: 3081.9922
# Validation Loss: 3094.6969
# Epoch [1601/2000], Loss: 3082.0301
# Validation Loss: 3042.9520
# Epoch [1621/2000], Loss: 3084.4294
# Validation Loss: 3071.5271
# Epoch [1641/2000], Loss: 3080.7040
# Validation Loss: 3045.8951
# Epoch [1661/2000], Loss: 3082.2594
# Validation Loss: 3053.1732
# Epoch [1681/2000], Loss: 3078.5067
# Validation Loss: 3045.6243
# Epoch [1701/2000], Loss: 3075.2346
# Validation Loss: 3072.3939
# Epoch [1721/2000], Loss: 3077.4640
# Validation Loss: 3036.3014
# Epoch [1741/2000], Loss: 3076.2195
# Validation Loss: 3098.5521
# Epoch [1761/2000], Loss: 3073.1406
# Validation Loss: 3098.4593
# Epoch [1781/2000], Loss: 3074.4903
# Validation Loss: 3125.1723
# Epoch [1801/2000], Loss: 3071.8272
# Validation Loss: 3100.7080
# Epoch [1821/2000], Loss: 3070.7438
# Validation Loss: 3100.6676
# Epoch [1841/2000], Loss: 3067.4337
# Validation Loss: 3056.6106
# Epoch [1861/2000], Loss: 3067.1714
# Validation Loss: 3052.2544
# Epoch [1881/2000], Loss: 3060.7711
# Validation Loss: 3064.0579
# Epoch [1901/2000], Loss: 3065.5252
# Validation Loss: 3044.5918
# Epoch [1921/2000], Loss: 3065.8471
# Validation Loss: 3110.6941
# Epoch [1941/2000], Loss: 3063.9371
# Validation Loss: 3061.0100
# Epoch [1961/2000], Loss: 3060.1096
# Validation Loss: 3098.3233
# Epoch [1981/2000], Loss: 3060.5299
# Validation Loss: 3078.3710
# Y:\analysis\fmats\e200\days\e200_day070_plane0_Fall.mat
# (11812, 2)
# cuda:0
# Epoch [1/2000], Loss: 7530.0483
# Validation Loss: 7626.0926
# Epoch [21/2000], Loss: 5851.8435
# Validation Loss: 5914.5245
# Epoch [41/2000], Loss: 5368.0821
# Validation Loss: 5424.8918
# Epoch [61/2000], Loss: 4955.8849
# Validation Loss: 4995.3855
# Epoch [81/2000], Loss: 4570.3280
# Validation Loss: 4605.0689
# Epoch [101/2000], Loss: 4230.6080
# Validation Loss: 4259.9320
# Epoch [121/2000], Loss: 3940.1175
# Validation Loss: 3955.8469
# Epoch [141/2000], Loss: 3682.7267
# Validation Loss: 3692.0183
# Epoch [161/2000], Loss: 3467.2183
# Validation Loss: 3468.0458
# Epoch [181/2000], Loss: 3294.3215
# Validation Loss: 3283.1548
# Epoch [201/2000], Loss: 3152.7543
# Validation Loss: 3135.5627
# Epoch [221/2000], Loss: 3049.8012
# Validation Loss: 3024.8849
# Epoch [241/2000], Loss: 2979.1685
# Validation Loss: 2949.0173
# Epoch [261/2000], Loss: 2940.9663
# Validation Loss: 2903.3503
# Epoch [281/2000], Loss: 2921.5680
# Validation Loss: 2881.4991
# Epoch [301/2000], Loss: 2918.9557
# Validation Loss: 2873.5512
# Epoch [321/2000], Loss: 2904.4208
# Validation Loss: 2890.9388
# Epoch [341/2000], Loss: 2876.0546
# Validation Loss: 2915.3096
# Epoch [361/2000], Loss: 2860.0885
# Validation Loss: 2910.2413
# Epoch [381/2000], Loss: 2847.5433
# Validation Loss: 2915.8966
# Epoch [401/2000], Loss: 2841.0045
# Validation Loss: 2920.7047
# Epoch [421/2000], Loss: 2834.5138
# Validation Loss: 2923.6752
# Epoch [441/2000], Loss: 2834.7343
# Validation Loss: 2925.4731
# Epoch [461/2000], Loss: 2832.0401
# Validation Loss: 2929.4702
# Epoch [481/2000], Loss: 2828.0685
# Validation Loss: 2931.8528
# Epoch [501/2000], Loss: 2826.5251
# Validation Loss: 2925.3882
# Epoch [521/2000], Loss: 2821.6852
# Validation Loss: 2924.6857
# Epoch [541/2000], Loss: 2825.2550
# Validation Loss: 2926.9027
# Epoch [561/2000], Loss: 2824.1701
# Validation Loss: 2923.2114
# Epoch [581/2000], Loss: 2822.6770
# Validation Loss: 2928.5545
# Epoch [601/2000], Loss: 2820.0120
# Validation Loss: 2922.7535
# Epoch [621/2000], Loss: 2817.8557
# Validation Loss: 2922.2259
# Epoch [641/2000], Loss: 2820.6704
# Validation Loss: 2925.1965
# Epoch [661/2000], Loss: 2816.8491
# Validation Loss: 2924.2122
# Epoch [681/2000], Loss: 2817.3265
# Validation Loss: 2927.8495
# Epoch [701/2000], Loss: 2814.0098
# Validation Loss: 2924.5319
# Epoch [721/2000], Loss: 2820.1946
# Validation Loss: 2925.8572
# Epoch [741/2000], Loss: 2818.3525
# Validation Loss: 2928.1165
# Epoch [761/2000], Loss: 2817.5246
# Validation Loss: 2926.5862
# Epoch [781/2000], Loss: 2815.7484
# Validation Loss: 2927.5911
# Epoch [801/2000], Loss: 2820.9987
# Validation Loss: 2930.8172
# Epoch [821/2000], Loss: 2816.0084
# Validation Loss: 2930.6937
# Epoch [841/2000], Loss: 2812.6930
# Validation Loss: 2936.5093
# Epoch [861/2000], Loss: 2812.9330
# Validation Loss: 2938.4999
# Epoch [881/2000], Loss: 2815.2697
# Validation Loss: 2933.8178
# Epoch [901/2000], Loss: 2814.7201
# Validation Loss: 2932.0779
# Epoch [921/2000], Loss: 2808.1591
# Validation Loss: 2945.8571
# Epoch [941/2000], Loss: 2809.8083
# Validation Loss: 2937.3489
# Epoch [961/2000], Loss: 2811.0646
# Validation Loss: 2938.3642
# Epoch [981/2000], Loss: 2809.3867
# Validation Loss: 2939.6229
# Epoch [1001/2000], Loss: 2810.8068
# Validation Loss: 2942.2591
# Epoch [1021/2000], Loss: 2810.1042
# Validation Loss: 2945.9324
# Epoch [1041/2000], Loss: 2808.6198
# Validation Loss: 2946.1444
# Epoch [1061/2000], Loss: 2811.9571
# Validation Loss: 2947.5484
# Epoch [1081/2000], Loss: 2809.4754
# Validation Loss: 2945.2519
# Epoch [1101/2000], Loss: 2809.3386
# Validation Loss: 2949.3507
# Epoch [1121/2000], Loss: 2809.4284
# Validation Loss: 2946.2210
# Epoch [1141/2000], Loss: 2811.4314
# Validation Loss: 2949.3902
# Epoch [1161/2000], Loss: 2813.7577
# Validation Loss: 2951.1549
# Epoch [1181/2000], Loss: 2809.0278
# Validation Loss: 2949.9611
# Epoch [1201/2000], Loss: 2806.2707
# Validation Loss: 2961.6228
# Epoch [1221/2000], Loss: 2810.1673
# Validation Loss: 2955.7290
# Epoch [1241/2000], Loss: 2806.3178
# Validation Loss: 2960.1974
# Epoch [1261/2000], Loss: 2808.5836
# Validation Loss: 2959.0452
# Epoch [1281/2000], Loss: 2804.0083
# Validation Loss: 2959.0499
# Epoch [1301/2000], Loss: 2807.9010
# Validation Loss: 2958.3456
# Epoch [1321/2000], Loss: 2805.6728
# Validation Loss: 2959.4494
# Epoch [1341/2000], Loss: 2802.9553
# Validation Loss: 2959.2713
# Epoch [1361/2000], Loss: 2802.2264
# Validation Loss: 2957.2517
# Epoch [1381/2000], Loss: 2804.9299
# Validation Loss: 2960.6042
# Epoch [1401/2000], Loss: 2803.5573
# Validation Loss: 2958.4370
# Epoch [1421/2000], Loss: 2804.3643
# Validation Loss: 2957.6653
# Epoch [1441/2000], Loss: 2803.8788
# Validation Loss: 2959.6747
# Epoch [1461/2000], Loss: 2801.5858
# Validation Loss: 2962.1183
# Epoch [1481/2000], Loss: 2800.5325
# Validation Loss: 2967.5440
# Epoch [1501/2000], Loss: 2799.1870
# Validation Loss: 2959.4682
# Epoch [1521/2000], Loss: 2803.4036
# Validation Loss: 2955.7410
# Epoch [1541/2000], Loss: 2800.7670
# Validation Loss: 2964.2731
# Epoch [1561/2000], Loss: 2795.7875
# Validation Loss: 2953.3465
# Epoch [1581/2000], Loss: 2796.1727
# Validation Loss: 2962.5279
# Epoch [1601/2000], Loss: 2798.0647
# Validation Loss: 2962.6985
# Epoch [1621/2000], Loss: 2796.6114
# Validation Loss: 2965.5799
# Epoch [1641/2000], Loss: 2795.6197
# Validation Loss: 2966.0061
# Epoch [1661/2000], Loss: 2793.8424
# Validation Loss: 2958.1606
# Epoch [1681/2000], Loss: 2789.6042
# Validation Loss: 2966.9565
# Epoch [1701/2000], Loss: 2795.6279
# Validation Loss: 2959.3694
# Epoch [1721/2000], Loss: 2790.4690
# Validation Loss: 2960.3101
# Epoch [1741/2000], Loss: 2790.8778
# Validation Loss: 2961.5725
# Epoch [1761/2000], Loss: 2790.0242
# Validation Loss: 2956.7642
# Epoch [1781/2000], Loss: 2788.5461
# Validation Loss: 2966.2515
# Epoch [1801/2000], Loss: 2787.4916
# Validation Loss: 2962.7670
# Epoch [1821/2000], Loss: 2786.0704
# Validation Loss: 2961.5488
# Epoch [1841/2000], Loss: 2783.2244
# Validation Loss: 2963.0673
# Epoch [1861/2000], Loss: 2784.4770
# Validation Loss: 2963.2147
# Epoch [1881/2000], Loss: 2782.1735
# Validation Loss: 2960.0311
# Epoch [1901/2000], Loss: 2782.8484
# Validation Loss: 2964.9106
# Epoch [1921/2000], Loss: 2778.6637
# Validation Loss: 2971.0304
# Epoch [1941/2000], Loss: 2779.3944
# Validation Loss: 2971.4014
# Epoch [1961/2000], Loss: 2776.2601
# Validation Loss: 2959.5883
# Epoch [1981/2000], Loss: 2774.7326
# Validation Loss: 2961.7200
# Y:\analysis\fmats\e200\days\e200_day072_plane0_Fall.mat
# (6702, 5)
# cuda:0
# Epoch [1/2000], Loss: 12872.1674
# Validation Loss: 13028.4164
# Epoch [21/2000], Loss: 10994.9555
# Validation Loss: 11133.0371
# Epoch [41/2000], Loss: 10509.0071
# Validation Loss: 10650.7850
# Epoch [61/2000], Loss: 10087.6905
# Validation Loss: 10220.1695
# Epoch [81/2000], Loss: 9679.9283
# Validation Loss: 9812.7672
# Epoch [101/2000], Loss: 9302.6963
# Validation Loss: 9422.2591
# Epoch [121/2000], Loss: 8916.0943
# Validation Loss: 9042.7879
# Epoch [141/2000], Loss: 8549.6693
# Validation Loss: 8679.1068
# Epoch [161/2000], Loss: 8200.2789
# Validation Loss: 8328.9603
# Epoch [181/2000], Loss: 7872.3682
# Validation Loss: 7992.4070
# Epoch [201/2000], Loss: 7545.9976
# Validation Loss: 7666.9911
# Epoch [221/2000], Loss: 7244.0586
# Validation Loss: 7354.7956
# Epoch [241/2000], Loss: 6944.2953
# Validation Loss: 7056.8022
# Epoch [261/2000], Loss: 6663.9156
# Validation Loss: 6772.1773
# Epoch [281/2000], Loss: 6399.8009
# Validation Loss: 6497.9685
# Epoch [301/2000], Loss: 6144.1967
# Validation Loss: 6238.7259
# Epoch [321/2000], Loss: 5895.6011
# Validation Loss: 5992.8264
# Epoch [341/2000], Loss: 5668.1834
# Validation Loss: 5760.2218
# Epoch [361/2000], Loss: 5451.9040
# Validation Loss: 5540.7209
# Epoch [381/2000], Loss: 5247.0719
# Validation Loss: 5334.5761
# Epoch [401/2000], Loss: 5058.7255
# Validation Loss: 5141.4504
# Epoch [421/2000], Loss: 4882.9703
# Validation Loss: 4961.3567
# Epoch [441/2000], Loss: 4715.6502
# Validation Loss: 4794.3393
# Epoch [461/2000], Loss: 4568.3515
# Validation Loss: 4639.9930
# Epoch [481/2000], Loss: 4430.2773
# Validation Loss: 4498.4235
# Epoch [501/2000], Loss: 4306.6112
# Validation Loss: 4369.5215
# Epoch [521/2000], Loss: 4189.9569
# Validation Loss: 4253.1425
# Epoch [541/2000], Loss: 4090.4763
# Validation Loss: 4149.0070
# Epoch [561/2000], Loss: 3996.9165
# Validation Loss: 4057.0833
# Epoch [581/2000], Loss: 3920.9976
# Validation Loss: 3977.1934
# Epoch [601/2000], Loss: 3856.4086
# Validation Loss: 3909.0843
# Epoch [621/2000], Loss: 3801.5915
# Validation Loss: 3852.2680
# Epoch [641/2000], Loss: 3760.0113
# Validation Loss: 3806.5695
# Epoch [661/2000], Loss: 3727.4812
# Validation Loss: 3771.0121
# Epoch [681/2000], Loss: 3703.8194
# Validation Loss: 3744.8585
# Epoch [701/2000], Loss: 3690.5345
# Validation Loss: 3726.6005
# Epoch [721/2000], Loss: 3676.6458
# Validation Loss: 3714.9956
# Epoch [741/2000], Loss: 3670.0766
# Validation Loss: 3708.1608
# Epoch [761/2000], Loss: 3670.0036
# Validation Loss: 3704.5809
# Epoch [781/2000], Loss: 3668.4247
# Validation Loss: 3702.7460
# Epoch [801/2000], Loss: 3281.4782
# Validation Loss: 3108.8886
# Epoch [821/2000], Loss: 3028.7945
# Validation Loss: 2862.7513
# Epoch [841/2000], Loss: 2903.0944
# Validation Loss: 2786.7194
# Epoch [861/2000], Loss: 2845.9308
# Validation Loss: 2716.7277
# Epoch [881/2000], Loss: 2802.1346
# Validation Loss: 2687.3950
# Epoch [901/2000], Loss: 2766.2427
# Validation Loss: 2591.0647
# Epoch [921/2000], Loss: 2737.9947
# Validation Loss: 2549.9875
# Epoch [941/2000], Loss: 2727.6488
# Validation Loss: 2506.0582
# Epoch [961/2000], Loss: 2692.1310
# Validation Loss: 2492.5832
# Epoch [981/2000], Loss: 2672.2066
# Validation Loss: 2452.3323
# Epoch [1001/2000], Loss: 2652.6304
# Validation Loss: 2416.6928
# Epoch [1021/2000], Loss: 2642.9801
# Validation Loss: 2423.5047
# Epoch [1041/2000], Loss: 2629.8509
# Validation Loss: 2385.3262
# Epoch [1061/2000], Loss: 2630.1714
# Validation Loss: 2375.1884
# Epoch [1081/2000], Loss: 2602.4550
# Validation Loss: 2372.0443
# Epoch [1101/2000], Loss: 2581.8483
# Validation Loss: 2346.0491
# Epoch [1121/2000], Loss: 2573.8781
# Validation Loss: 2354.1752
# Epoch [1141/2000], Loss: 2553.8077
# Validation Loss: 2335.9987
# Epoch [1161/2000], Loss: 2540.2935
# Validation Loss: 2337.0042
# Epoch [1181/2000], Loss: 2524.7450
# Validation Loss: 2317.0516
# Epoch [1201/2000], Loss: 2496.7548
# Validation Loss: 2273.9980
# Epoch [1221/2000], Loss: 2475.9119
# Validation Loss: 2253.4056
# Epoch [1241/2000], Loss: 2456.1117
# Validation Loss: 2224.8116
# Epoch [1261/2000], Loss: 2443.8299
# Validation Loss: 2226.7613
# Epoch [1281/2000], Loss: 2424.0697
# Validation Loss: 2230.9639
# Epoch [1301/2000], Loss: 2395.5463
# Validation Loss: 2185.3776
# Epoch [1321/2000], Loss: 2388.9953
# Validation Loss: 2182.9022
# Epoch [1341/2000], Loss: 2381.5502
# Validation Loss: 2171.8371
# Epoch [1361/2000], Loss: 2360.1439
# Validation Loss: 2161.3008
# Epoch [1381/2000], Loss: 2342.0359
# Validation Loss: 2130.9480
# Epoch [1401/2000], Loss: 2347.5944
# Validation Loss: 2112.9527
# Epoch [1421/2000], Loss: 2331.4396
# Validation Loss: 2130.7226
# Epoch [1441/2000], Loss: 2316.4969
# Validation Loss: 2118.9423
# Epoch [1461/2000], Loss: 2310.3361
# Validation Loss: 2156.5284
# Epoch [1481/2000], Loss: 2295.0431
# Validation Loss: 2093.6396
# Epoch [1501/2000], Loss: 2269.0718
# Validation Loss: 2162.0077
# Epoch [1521/2000], Loss: 2269.4852
# Validation Loss: 2073.9772
# Epoch [1541/2000], Loss: 2259.7276
# Validation Loss: 2082.5838
# Epoch [1561/2000], Loss: 2241.4253
# Validation Loss: 2101.9158
# Epoch [1581/2000], Loss: 2236.6405
# Validation Loss: 2078.5117
# Epoch [1601/2000], Loss: 2227.7556
# Validation Loss: 2082.2300
# Epoch [1621/2000], Loss: 2219.3348
# Validation Loss: 2048.1292
# Epoch [1641/2000], Loss: 2209.8741
# Validation Loss: 2048.2442
# Epoch [1661/2000], Loss: 2197.6923
# Validation Loss: 2075.7368
# Epoch [1681/2000], Loss: 2188.6042
# Validation Loss: 2057.2222
# Epoch [1701/2000], Loss: 2176.4757
# Validation Loss: 2064.7518
# Epoch [1721/2000], Loss: 2175.9943
# Validation Loss: 2084.3934
# Epoch [1741/2000], Loss: 2174.4864
# Validation Loss: 2091.5403
# Epoch [1761/2000], Loss: 2166.2487
# Validation Loss: 2057.0819
# Epoch [1781/2000], Loss: 2144.4477
# Validation Loss: 2076.1207
# Epoch [1801/2000], Loss: 2136.9623
# Validation Loss: 2084.9585
# Epoch [1821/2000], Loss: 2124.7226
# Validation Loss: 2060.4767
# Epoch [1841/2000], Loss: 2123.4370
# Validation Loss: 2086.4768
# Epoch [1861/2000], Loss: 2109.3768
# Validation Loss: 2066.9174
# Epoch [1881/2000], Loss: 2096.8460
# Validation Loss: 2077.9310
# Epoch [1901/2000], Loss: 2100.9087
# Validation Loss: 2089.6867
# Epoch [1921/2000], Loss: 2074.9946
# Validation Loss: 2090.6181
# Epoch [1941/2000], Loss: 2061.8182
# Validation Loss: 2054.6917
# Epoch [1961/2000], Loss: 2046.7274
# Validation Loss: 2107.3918
# Epoch [1981/2000], Loss: 2043.2890
# Validation Loss: 2091.0242
# Y:\analysis\fmats\e200\days\e200_day073_plane0_Fall.mat
# (9544, 2)
# cuda:0
# Epoch [1/2000], Loss: 8294.4587
# Validation Loss: 7782.6673
# Epoch [21/2000], Loss: 6524.5523
# Validation Loss: 6067.1810
# Epoch [41/2000], Loss: 6045.2608
# Validation Loss: 5610.0061
# Epoch [61/2000], Loss: 5613.9255
# Validation Loss: 5206.5606
# Epoch [81/2000], Loss: 5226.0096
# Validation Loss: 4834.4756
# Epoch [101/2000], Loss: 4860.9923
# Validation Loss: 4485.9922
# Epoch [121/2000], Loss: 4519.7227
# Validation Loss: 4167.8662
# Epoch [141/2000], Loss: 4207.4095
# Validation Loss: 3876.5621
# Epoch [161/2000], Loss: 3927.3359
# Validation Loss: 3610.0409
# Epoch [181/2000], Loss: 3669.0078
# Validation Loss: 3370.7182
# Epoch [201/2000], Loss: 3437.8577
# Validation Loss: 3157.7936
# Epoch [221/2000], Loss: 3235.7849
# Validation Loss: 2970.9207
# Epoch [241/2000], Loss: 3051.2829
# Validation Loss: 2809.6303
# Epoch [261/2000], Loss: 2899.9273
# Validation Loss: 2673.8514
# Epoch [281/2000], Loss: 2767.5331
# Validation Loss: 2562.0251
# Epoch [301/2000], Loss: 2664.8457
# Validation Loss: 2474.2093
# Epoch [321/2000], Loss: 2585.5441
# Validation Loss: 2409.6581
# Epoch [341/2000], Loss: 2528.7054
# Validation Loss: 2366.5021
# Epoch [361/2000], Loss: 2487.8283
# Validation Loss: 2342.0057
# Epoch [381/2000], Loss: 2468.5328
# Validation Loss: 2332.2737
# Epoch [401/2000], Loss: 2452.3978
# Validation Loss: 2331.5371
# Epoch [421/2000], Loss: 2455.6674
# Validation Loss: 2333.8487
# Epoch [441/2000], Loss: 2453.3078
# Validation Loss: 2335.9103
# Epoch [461/2000], Loss: 2453.5817
# Validation Loss: 2337.0398
# Epoch [481/2000], Loss: 2454.7527
# Validation Loss: 2337.4752
# Epoch [501/2000], Loss: 2453.3639
# Validation Loss: 2337.6366
# Epoch [521/2000], Loss: 2455.2051
# Validation Loss: 2337.7696
# Epoch [541/2000], Loss: 2452.4614
# Validation Loss: 2336.7980
# Epoch [561/2000], Loss: 2452.4767
# Validation Loss: 2336.5292
# Epoch [581/2000], Loss: 2451.4610
# Validation Loss: 2336.3847
# Epoch [601/2000], Loss: 2441.2833
# Validation Loss: 2316.4642
# Epoch [621/2000], Loss: 2439.0339
# Validation Loss: 2315.0434
# Epoch [641/2000], Loss: 2436.4656
# Validation Loss: 2316.8314
# Epoch [661/2000], Loss: 2442.1500
# Validation Loss: 2312.1402
# Epoch [681/2000], Loss: 2438.7378
# Validation Loss: 2313.1717
# Epoch [701/2000], Loss: 2440.2791
# Validation Loss: 2313.1208
# Epoch [721/2000], Loss: 2430.3368
# Validation Loss: 2295.7102
# Epoch [741/2000], Loss: 2433.9131
# Validation Loss: 2296.9288
# Epoch [761/2000], Loss: 2431.5834
# Validation Loss: 2300.9332
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 92
#      89 train_loss = 0.0
#      90 for inputs, targets in Train_loader:
#      91     # Forward pass
# ---> 92     inputs, targets = inputs.to(device).float(), targets.to(device).float()
#      93     outputs = model(inputs)
#      94     loss = criterion(outputs, targets)
#
# KeyboardInterrupt:

# %%
# load existing model
savepth = rf'Z:\\model_dd{dd}_conddct.pt'
print(dd)
model = LSTMModel(input_size, output_dim = output_size)
model.load_state_dict(torch.load(savepth))
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
model = model.to(device)
criterion = nn.MSELoss()  # For regression tasks
# criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-5, 
            weight_decay = 1e-9)

# use model to predict position
dff_test = dff_per_ep_trials_test[comp[1]]
# TODO: use a couple trials from same ep as testing
# use different epochs for further testing
pos = position_per_ep_trials_test[comp[1]]
pos = pos[TimeInterval-1:].reshape(-1,1)
lick = licks_per_ep_trials_test[comp[1]]

TestData = create_subsequences(dff_test,TimeInterval)
input_size = TestData.shape[-1] # number of cells
output_size = 1

Test_dataset = CreateTimeSeriesData(TestData, pos)
Test_loader = DataLoader(dataset=Test_dataset, batch_size=batch_size, 
                        shuffle=False, drop_last = True)
predict = []
val_loss = 0
for inputs, targets in Test_loader:
    # Forward pass
    inputs, targets = inputs.to(device).float(), targets.to(device).float()
    outputs = model(inputs)
    predict.append(outputs)
    loss = criterion(outputs, targets)
    val_loss += loss.item()
print('Validation Loss: {:.4f}'.format(val_loss/len(Test_loader)))
# Out:
# 17
# cuda:0
# Validation Loss: 1451.2895

# %%
predict = np.concatenate([xx.cpu().detach().numpy() for xx in predict])

# %%
fig, axes = plt.subplots(1,3, figsize=(15,7))
axes[0].plot(pos)
axes[1].plot(predict)
axes[2].plot(pos)
axes[2].plot(predict)
axes[0].scatter(np.where(lick>0)[0], pos[np.where(lick>0)[0]], s=5, color='k')
axes[1].scatter(np.where(lick>0)[0], pos[np.where(lick>0)[0]], s=5, color='k')

# %%
print(pos.shape)
print(predict.shape)
# Compute the MAE and MSE on a test set
from sklearn.metrics import mean_absolute_error, mean_squared_error
if pos.shape[0]>predict.shape[0]:
    pos = pos[:predict.shape[0]]
mae = mean_absolute_error(pos, predict)
mse = mean_squared_error(pos, predict)
print(f"MAE: {mae:.4f}, MSE: {mse:.4f}")
# Out:
# (2723, 1)
# (2688, 1)
# MAE: 29.9775, MSE: 1451.2895
